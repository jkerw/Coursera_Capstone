# %% [markdown]
# # Coursera Capstone Project
# ## The Battle of Neighborhoods - Final Report
#
# ### Content
#
# #### 1. Introduction
#
#     1.1 Background Discussion
#
#     1.2 Description of the Data and Use
#
#
# #### 2. Methodology
#
#
#     2.1 Description of Analysis
#
#
# #### 3. Results
#
#
#     3.1 Discussion of Results
#
#
# #### 4. Discussion
#
#
#     4.1 Discussion of Observations
#
#     4.2 Recommendations
#
#
# #### 5. Conclusion
#
#
#     5.1 Summary
#
# #### 6. Code
#
#     6. Libraries Uploaded

# %% [markdown]
# ## 1. Introduction
#
# ### 1.1 Background Discussion
#
# I am a Project Manager residing in the Midwest. My company will be moving me to NYC in a few months and I need to find a new home. I like to be within walking distance to local restaurants and a grocer, if possible. My primary mode of transportation is my bicycle and public transportation. I will be using this assignment as a way to help me narrow down my potential living options.
#
# ### 1.2 Description of the Data and Use
#
# The challenge will be finding a place to rent that offers the same benefits as my current residence. I will need to find a living space that meets these conditions:
#
# <ul>
# <li>Less than 2 miles from a public transportation hub</li>
# <li>Area with at least three restaurants within walking distance</li>
# <li>At least one grocer in the immediate area</li>
# </ul>
#
# This project is relevant to anyone who may find themselves moving to a new area, especially if it is their first move and do not really know what to look for. My first move was a disaster because I did not truly understand what I was looking for.
#
# The Foursquare mapping API will be combined with data analysis to help meet the above criteria.
#
# I use Foursquare to identify areas meeting my minimum criteria as stated above.
#
# #### Information required:
#
# A list of neighborhoods within the Bronx area and associated latitude and longitude. A dataframe will be created using Pandas to display the map. Nominatim will be used to determine the geographical data. A variety of statistical tools will be used to identify the ideal neighborhood.

# %% [markdown]
# ## 2. Methodology
#
# #### 2.1:
#
# I looked at each neighborhood in the Bronx to determine the density of grocers, transportation hubs and restaraunts in the area to determine the ideal location to live. I looked at the mean in each neighborhood to determine the highest density for each of my required categories.

# %% [markdown]
# ## 3. Results
#
# #### 3.1:
#
# I have determined Claremont Village is the ideal location for me to find a place to live according to the parameters set forth. Secondly, Soundview would be an acceptable neighborhood if I determine Claremont Village is unaffordable. The cost of living is outside the scope of this assignment and will not be analyzed.

# %% [markdown]
# ## 4. Discussion
#
# #### 4.1:
#
# Claremont Village offers the highest density of public transportation, grocers and pizza places. If I were to specify a variety of restaurants and increase the limit to 5, instead of 3, I would be curious if Claremont Village is still the best option. Soundview came in at a close second, lacking in public transportation, but having a greater variety of restaraunts.
#
# #### 4.2:
#
# Claremont Village suits my needs based off the above parameters the best.

# %% [markdown]
# ## 5. Conclusion
#
# #### 5.1:
#
# I will begin my housing search in Claremont Village, expanding to Soundview, if necessary.

# %% [markdown]
# ## 6. Code

# %%
import numpy as np 

import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json 

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 

import requests 
from pandas.io.json import json_normalize 


import matplotlib.cm as cm
import matplotlib.colors as colors


from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes 
import folium 

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     certifi-2019.11.28         |   py36h9f0ad1d_1         149 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     openssl-1.1.1e             |       h516909a_0         2.1 MB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
neighborhoods_data = newyork_data['features']
neighborhoods_data[0]
# Out:
# {'type': 'Feature',
#  'id': 'nyu_2451_34572.1',
#  'geometry': {'type': 'Point',
#   'coordinates': [-73.84720052054902, 40.89470517661]},
#  'geometry_name': 'geom',
#  'properties': {'name': 'Wakefield',
#   'stacked': 1,
#   'annoline1': 'Wakefield',
#   'annoline2': None,
#   'annoline3': None,
#   'annoangle': 0.0,
#   'borough': 'Bronx',
#   'bbox': [-73.84720052054902,
#    40.89470517661,
#    -73.84720052054902,
#    40.89470517661]}}

# %%
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
neighborhoods.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
bronx_data = neighborhoods[neighborhoods['Borough'] == 'Bronx'].reset_index(drop=True)
bronx_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
address = 'Bronx, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

print('The geograpical coordinate of Bronx are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Bronx are 40.8466508, -73.8785937.

# %%
map_bronx = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lng, label in zip(bronx_data['Latitude'], bronx_data['Longitude'], bronx_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_bronx)  
    
map_bronx
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'YOUR FOURSQUARE ID'
CLIENT_SECRET = 'YOUR FOURSQUARE SECRET' 
VERSION = '20180605' 

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: YOUR FOURSQUARE ID
# CLIENT_SECRET:YOUR FOURSQUARE SECRET

# %%
bronx_data.loc[0, 'Neighborhood']
# Out:
# 'Wakefield'

# %%
neighborhood_latitude = bronx_data.loc[0, 'Latitude']
neighborhood_longitude = bronx_data.loc[0, 'Longitude'] 

neighborhood_name = bronx_data.loc[0, 'Neighborhood'] 

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Wakefield are 40.89470517661, -73.84720052054902.

# %%
LIMIT = 50

radius = 500

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e7ff59f618f43001b8bbcab'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Wakefield',
#   'headerFullLocation': 'Wakefield, Bronx',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 10,
#   'suggestedBounds': {'ne': {'lat': 40.899205181110005,
#     'lng': -73.84125857127495},
#    'sw': {'lat': 40.89020517211, 'lng': -73.8531424698231}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c537892fd2ea593cb077a28',
#        'name': 'Lollipops Gelato',
#        'location': {'address': '4120 Baychester Ave',
#         'crossStreet': 'Edenwald & Bussing Ave',
#         'lat': 40.894123150205274,
# ...

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) 

filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]


nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)


nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                name      categories        lat        lng
# 0  Lollipops Gelato    Dessert Shop  40.894123 -73.845892
# 1          Rite Aid        Pharmacy  40.896649 -73.844846
# 2  Carvel Ice Cream  Ice Cream Shop  40.890487 -73.848568
# 3         Walgreens        Pharmacy  40.896528 -73.844700
# 4           Dunkin'      Donut Shop  40.890459 -73.849089

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
bronx_venues = getNearbyVenues(names=bronx_data['Neighborhood'],
                                   latitudes=bronx_data['Latitude'],
                                   longitudes=bronx_data['Longitude']
                                  )
# Out:
# Wakefield
# Co-op City
# Eastchester
# Fieldston
# Riverdale
# Kingsbridge
# Woodlawn
# Norwood
# Williamsbridge
# Baychester
# Pelham Parkway
# City Island
# Bedford Park
# University Heights
# Morris Heights
# Fordham
# East Tremont
# West Farms
# High  Bridge
# Melrose
# Mott Haven
# Port Morris
# Longwood
# Hunts Point
# Morrisania
# Soundview
# Clason Point
# Throgs Neck
# Country Club
# Parkchester
# Westchester Square
# Van Nest
# Morris Park
# Belmont
# Spuyten Duyvil
# North Riverdale
# Pelham Bay
# Schuylerville
# Edgewater Park
# Castle Hill
# Olinville
# Pelham Gardens
# Concourse
# Unionport
# Edenwald
# Claremont Village
# Concourse Village
# Mount Eden
# Mount Hope
# Bronxdale
# Allerton
# Kingsbridge Heights
# Wakefield
# Co-op City
# Eastchester
# Fieldston
# Riverdale
# Kingsbridge
# Woodlawn
# Norwood
# Williamsbridge
# Baychester
# Pelham Parkway
# City Island
# Bedford Park
# University Heights
# Morris Heights
# Fordham
# East Tremont
# West Farms
# ...

# %%
bronx_venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0    Wakefield              40.894705              -73.847201
# 1    Wakefield              40.894705              -73.847201
# 2    Wakefield              40.894705              -73.847201
# 3    Wakefield              40.894705              -73.847201
# 4    Wakefield              40.894705              -73.847201
#
#               Venue  Venue Latitude  Venue Longitude  Venue Category
# 0  Lollipops Gelato       40.894123       -73.845892    Dessert Shop
# 1          Rite Aid       40.896649       -73.844846        Pharmacy
# 2  Carvel Ice Cream       40.890487       -73.848568  Ice Cream Shop
# 3         Walgreens       40.896528       -73.844700        Pharmacy
# 4           Dunkin'       40.890459       -73.849089      Donut Shop

# %%
bronx_venues.groupby('Neighborhood').count()
# Out:
#                      Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Allerton                                84                      84     84
# Baychester                              60                      60     60
# Bedford Park                            99                      99     99
# Belmont                                150                     150    150
# Bronxdale                               39                      39     39
# Castle Hill                             24                      24     24
# City Island                             75                      75     75
# Claremont Village                       57                      57     57
# Clason Point                            30                      30     30
# Co-op City                              54                      54     54
# Concourse                               84                      84     84
# ...

# %%
bronx_onehot = pd.get_dummies(bronx_venues[['Venue Category']], prefix="", prefix_sep="")

bronx_onehot['Neighborhood'] = bronx_venues['Neighborhood'] 

fixed_columns = [bronx_onehot.columns[-1]] + list(bronx_onehot.columns[:-1])
bronx_onehot = bronx_onehot[fixed_columns]

# %%
bronx_grouped = bronx_onehot.groupby('Neighborhood').mean().reset_index()
bronx_grouped
# Out:
#            Neighborhood  Accessories Store  African Restaurant  \
# 0              Allerton           0.000000            0.000000
# 1            Baychester           0.000000            0.000000
# 2          Bedford Park           0.000000            0.000000
# 3               Belmont           0.000000            0.000000
# 4             Bronxdale           0.000000            0.000000
# 5           Castle Hill           0.000000            0.000000
# 6           City Island           0.000000            0.000000
# 7     Claremont Village           0.000000            0.000000
# 8          Clason Point           0.000000            0.000000
# 9            Co-op City           0.055556            0.000000
# 10            Concourse           0.000000            0.000000
# 11    Concourse Village           0.000000            0.000000
# 12         Country Club           0.000000            0.000000
# 13         East Tremont           0.000000            0.000000
# ...

# %%
num_top_venues = 3

for hood in bronx_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = bronx_grouped[bronx_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Allerton----
#            venue  freq
# 0    Pizza Place  0.14
# 1    Bus Station  0.07
# 2  Deli / Bodega  0.07
#
#
# ----Baychester----
#                   venue  freq
# 0            Donut Shop  0.10
# 1            Playground  0.05
# 2  Gym / Fitness Center  0.05
#
#
# ----Bedford Park----
#                 venue  freq
# 0               Diner  0.12
# 1  Chinese Restaurant  0.12
# 2         Pizza Place  0.09
#
#
# ----Belmont----
#                 venue  freq
# 0  Italian Restaurant  0.32
# 1         Pizza Place  0.12
# 2       Deli / Bodega  0.10
#
#
# ----Bronxdale----
#                          venue  freq
# 0           Mexican Restaurant  0.08
# 1                          Gym  0.08
# 2  Eastern European Restaurant  0.08
#
#
# ----Castle Hill----
#          venue  freq
# 0  Pizza Place  0.25
# 1     Pharmacy  0.12
# 2        Diner  0.12
#
#
# ----City Island----
#                     venue  freq
# 0         Harbor / Marina  0.12
# 1      Seafood Restaurant  0.08
# ...
